# %% [markdown]
# # Hand writting neural network
#
# This notebook will work on implementing a neurone only using numpy and maths.
#
# **Main goals are**:
#  - Understand how thing works by implementing it

# %%
#Importing necessary libs to generate random dataset
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=100, n_features=2, centers=2, random_state=0)
y = y.reshape((y.shape[0], 1))

print('dimensions de X:', X.shape)
print('dimensions de y:', y.shape)

plt.scatter(X[:,0], X[:, 1], c=y, cmap='summer')
plt.show()
# Out:
# dimensions de X: (100, 2)
# dimensions de y: (100, 1)

# %%
from local_lib.neuron import LinearNeuron

neuron = LinearNeuron(X)

neuron.fit(X, y)
# Out:
# [2.228185598755876,
#  2.0797064038525446,
#  1.933335862844006,
#  1.7895287358831287,
#  1.6488238952792134,
#  1.511850301873766,
#  1.3793293831380478,
#  1.252072161996373,
#  1.1309688265274165,
#  1.016966958423996,
#  0.9110321999391091,
#  0.8140831613482945,
#  0.7268951547113472,
#  0.6499805190276784,
#  0.5834762124879178,
#  0.5270859222125022,
#  0.4801108329328269,
#  0.44156058013183747,
#  0.41029820274184065,
#  0.38516986289799277,
#  0.3650939542986016,
#  0.34910885294193883,
#  0.336390287895201,
#  0.32625028468242534,
#  0.3181264085945102,
#  0.31156666797747395,
#  0.3062131317337772,
#  0.3017859614272823,
#  0.2980687837554807,
#  0.29489586087611336,
#  0.2921412135687715,
#  0.28970965434342877,
#  0.28752956649600303,
#  0.28554720267234385,
#  0.2837222567662251,
#  0.2820244713891966,
#  0.28043106759745895,
#  0.27892481503753597,
#  0.2774925932182131,
#  0.2761243247774489,
#  0.27481218774756616,
#  0.27355003545678014,
#  0.2723329700363834,
# ...

# %%
from sklearn.metrics import accuracy_score

neuron = LinearNeuron(X, lr=0.5)

loss = neuron.fit(X, y)
y_pred= neuron.predict(X)

accuracy_score(y, y_pred)
# Out:
# 0.91

# %%
plt.plot(loss)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(X[:,0], X[:, 1], c=y, cmap='summer')

x1 = np.linspace(-1, 4, 100)
x2 = ( - neuron.W[0] * x1 - neuron.b) / neuron.W[1]

ax.plot(x1, x2, c='orange', lw=3)
